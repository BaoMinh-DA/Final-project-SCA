# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as seaborn
import statsmodels.api as sm
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/bài tập/Indian_housing_Delhi_data.csv')

# %%
df.head()
# Out:
#                  house_type   house_size           location   city   latitude  \
# 0    1 RK Studio Apartment     400 sq ft            Kalkaji  Delhi  28.545561
# 1    1 RK Studio Apartment     400 sq ft  Mansarover Garden  Delhi  28.643259
# 2  2 BHK Independent Floor     500 sq ft        Uttam Nagar  Delhi  28.618677
# 3  3 BHK Independent House   1,020 sq ft         Model Town  Delhi  28.712898
# 4          2 BHK Apartment     810 sq ft   Sector 13 Rohini  Delhi  28.723539
#
#    longitude  price currency  numBathrooms  numBalconies isNegotiable  \
# 0  77.254349  22000      INR           1.0           NaN          NaN
# 1  77.132828  20000      INR           1.0           NaN          NaN
# 2  77.053352   8500      INR           1.0           NaN          NaN
# 3  77.180000  48000      INR           3.0           NaN          NaN
# 4  77.131424  20000      INR           2.0           NaN          NaN
#
#    priceSqFt    verificationDate  \
# 0        NaN    Posted a day ago
# 1        NaN   Posted 9 days ago
# 2        NaN  Posted 12 days ago
# 3        NaN   Posted a year ago
# 4        NaN   Posted a year ago
#
#                                          description SecurityDeposit  \
# 0  Fully furnished, loaded with amenities & gadge...      No Deposit
# 1  Here is an excellent 1 BHK Independent Floor a...      No Deposit
# 2  Zero Brokerage.\n\n2 Room set, Govt bijali Met...      No Deposit
# 3  Itâs a 3 bhk independent house situated in M...      No Deposit
# 4  Well designed 2 bhk multistorey apartment is a...      No Deposit
#
#            Status
# 0       Furnished
# 1       Furnished
# 2  Semi-Furnished
# 3       Furnished
# 4     Unfurnished

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   house_type        5000 non-null   object
#  1   house_size        5000 non-null   object
#  2   location          5000 non-null   object
#  3   city              5000 non-null   object
#  4   latitude          5000 non-null   float64
#  5   longitude         5000 non-null   float64
#  6   price             5000 non-null   int64
#  7   currency          5000 non-null   object
#  8   numBathrooms      4975 non-null   float64
#  9   numBalconies      2737 non-null   float64
#  10  isNegotiable      179 non-null    object
#  11  priceSqFt         0 non-null      float64
#  12  verificationDate  5000 non-null   object
#  13  description       4715 non-null   object
#  14  SecurityDeposit   5000 non-null   object
#  15  Status            5000 non-null   object
# dtypes: float64(5), int64(1), object(10)
# memory usage: 625.1+ KB

# %%
drop_cols=['priceSqFt','isNegotiable','SecurityDeposit','currency','description','city','verificationDate','location']
df = df.drop(drop_cols,axis=1)

# %%
df.head()
# Out:
#                  house_type   house_size  latitude  longitude  price  \
# 0    1 RK Studio Apartment     400 sq ft     28.55      77.25  22000
# 1    1 RK Studio Apartment     400 sq ft     28.64      77.13  20000
# 2  2 BHK Independent Floor     500 sq ft     28.62      77.05   8500
# 3  3 BHK Independent House   1,020 sq ft     28.71      77.18  48000
# 4          2 BHK Apartment     810 sq ft     28.72      77.13  20000
#
#    numBathrooms  numBalconies          Status
# 0          1.00           NaN       Furnished
# 1          1.00           NaN       Furnished
# 2          1.00           NaN  Semi-Furnished
# 3          3.00           NaN       Furnished
# 4          2.00           NaN     Unfurnished

# %%
df['num_bed'] = df['house_type'].str.split(' ',expand=True)[0]
df['BHK/RK'] = df['house_type'].str.split(' ',expand=True)[1]
df['House_type'] = df['house_type'].str.split(' ',expand=True)[2]
df['house_size(SqFt)']= df['house_size'].str.split(' ',expand=True)[0]

# %%
df.head()
# Out:
#                  house_type   house_size  latitude  longitude  price  \
# 0    1 RK Studio Apartment     400 sq ft     28.55      77.25  22000
# 1    1 RK Studio Apartment     400 sq ft     28.64      77.13  20000
# 2  2 BHK Independent Floor     500 sq ft     28.62      77.05   8500
# 3  3 BHK Independent House   1,020 sq ft     28.71      77.18  48000
# 4          2 BHK Apartment     810 sq ft     28.72      77.13  20000
#
#    numBathrooms  numBalconies          Status num_bed BHK/RK   House_type  \
# 0          1.00           NaN       Furnished       1     RK       Studio
# 1          1.00           NaN       Furnished       1     RK       Studio
# 2          1.00           NaN  Semi-Furnished       2    BHK  Independent
# 3          3.00           NaN       Furnished       3    BHK  Independent
# 4          2.00           NaN     Unfurnished       2    BHK    Apartment
#
#   house_size(SqFt)
# 0              400
# 1              400
# 2              500
# 3            1,020
# 4              810

# %%
drop_cols = ['house_type','house_size']
df = df.drop(drop_cols,axis=1)

# %%
df.head()
# Out:
#    latitude  longitude  price  numBathrooms  numBalconies          Status  \
# 0     28.55      77.25  22000          1.00           NaN       Furnished
# 1     28.64      77.13  20000          1.00           NaN       Furnished
# 2     28.62      77.05   8500          1.00           NaN  Semi-Furnished
# 3     28.71      77.18  48000          3.00           NaN       Furnished
# 4     28.72      77.13  20000          2.00           NaN     Unfurnished
#
#   num_bed BHK/RK   House_type house_size(SqFt)
# 0       1     RK       Studio              400
# 1       1     RK       Studio              400
# 2       2    BHK  Independent              500
# 3       3    BHK  Independent            1,020
# 4       2    BHK    Apartment              810

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   location          5000 non-null   object
#  1   city              5000 non-null   object
#  2   latitude          5000 non-null   float64
#  3   longitude         5000 non-null   float64
#  4   price             5000 non-null   int64
#  5   numBathrooms      4975 non-null   float64
#  6   numBalconies      2737 non-null   float64
#  7   verificationDate  5000 non-null   object
#  8   Status            5000 non-null   object
#  9   num_bed           5000 non-null   object
#  10  BHK/RK            5000 non-null   object
#  11  House_type        5000 non-null   object
#  12  house_size(SqFt)  5000 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 507.9+ KB

# %%
df['num_bed'] = df['num_bed'].astype('int')
df['numBathrooms'] = df['numBathrooms'].fillna(df['num_bed'].median())
df['numBalconies'] = df['numBalconies'].fillna(df['numBathrooms'].median())

# %%
df['house_size(SqFt)'] = df['house_size(SqFt)'].str.replace(',','')
num_cols = ['house_size(SqFt)','numBathrooms']
cat_cols = ['Status','BHK/RK','House_type']
df[num_cols] = df[num_cols].astype('int')
df[cat_cols] = df[cat_cols].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   latitude            5000 non-null   float64
#  1   longitude           5000 non-null   float64
#  2   price               5000 non-null   int64
#  3   numBathrooms        5000 non-null   int64
#  4   numBalconies        5000 non-null   float64
#  5   Status              5000 non-null   category
#  6   num_bed             5000 non-null   int64
#  7   BHK/RK              5000 non-null   category
#  8   House_type          5000 non-null   category
#  9   house_size(SqFt)    5000 non-null   int64
#  10  distance_to_center  5000 non-null   int64
# dtypes: category(3), float64(3), int64(5)
# memory usage: 327.7 KB

# %%
from geopy.distance import geodesic

# %%
centrer_delhi = ['28.6815','77.2228']
def calculate_distance(row, centrer_delhi):
  point = (row['latitude'], row['longitude'])
  return geodesic(point, centrer_delhi).kilometers

# %%
df['distance_to_center'] = df.apply(calculate_distance, axis=1, centrer_delhi=centrer_delhi)
df['distance_to_center'] = df['distance_to_center'].astype('int')

# %%
df.head()
# Out:
#    latitude  longitude  price  numBathrooms  numBalconies          Status  \
# 0     28.55      77.25  22000             1          3.00       Furnished
# 1     28.64      77.13  20000             1          3.00       Furnished
# 2     28.62      77.05   8500             1          3.00  Semi-Furnished
# 3     28.71      77.18  48000             3          3.00       Furnished
# 4     28.72      77.13  20000             2          3.00     Unfurnished
#
#    num_bed BHK/RK   House_type  house_size(SqFt)  distance_to_center
# 0        1     RK       Studio               400                  15
# 1        1     RK       Studio               400                   9
# 2        2    BHK  Independent               500                  17
# 3        3    BHK  Independent              1020                   5
# 4        2    BHK    Apartment               810                  10

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df.describe()
# Out:
#        latitude  longitude      price  numBathrooms  numBalconies  num_bed  \
# count   5000.00    5000.00    5000.00       5000.00       5000.00  5000.00
# mean      28.58      77.17  222173.82          2.92          2.43     3.10
# std        0.19       0.12  273984.30          1.09          0.66     1.16
# min       20.01      72.77    3000.00          1.00          1.00     1.00
# 25%       28.54      77.14   29500.00          2.00          2.00     2.00
# 50%       28.57      77.20  125000.00          3.00          2.00     3.00
# 75%       28.62      77.23  301102.00          4.00          3.00     4.00
# max       28.81      80.36 3010101.00         10.00          8.00    12.00
#
#        house_size(SqFt)  distance_to_center
# count           5000.00             5000.00
# mean            2982.89               14.36
# std             2168.66               22.57
# min              150.00                1.00
# 25%             1100.00               12.00
# 50%             2500.00               14.00
# 75%             5896.00               16.00
# max            14521.00             1023.00

# %%
plt.figure(figsize=(10, 6))
seaborn.boxplot(y=df['price'], color='skyblue')
plt.title('Box Plot of Rental Prices')
plt.ylabel('Price')
plt.show()

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df = df[(df['price'] >= lower_bound) & (df['price'] <= upper_bound)]

# %%
df.head()
# Out:
#    latitude  longitude  price  numBathrooms  numBalconies          Status  \
# 0     28.55      77.25  22000             1          3.00       Furnished
# 1     28.64      77.13  20000             1          3.00       Furnished
# 2     28.62      77.05   8500             1          3.00  Semi-Furnished
# 3     28.71      77.18  48000             3          3.00       Furnished
# 4     28.72      77.13  20000             2          3.00     Unfurnished
#
#    num_bed BHK/RK   House_type  house_size(SqFt)  distance_to_center
# 0        1     RK       Studio               400                  15
# 1        1     RK       Studio               400                   9
# 2        2    BHK  Independent               500                  17
# 3        3    BHK  Independent              1020                   5
# 4        2    BHK    Apartment               810                  10

# %%
plt.hist(df['price'],color  = 'blue')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['BHK/RK'],df['price'], color='skyblue')
plt.title('Rental Prices by BHK/RK')
plt.xlabel('BHK/RK')
plt.ylabel('Price')

plt.figure(figsize=(10, 6))
plt.bar(df['Status'],df['price'], color='blue')
plt.title('Rental Prices by status')
plt.xlabel('House Status')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['house_size(SqFt)'], df['price'], alpha=0.5)
plt.title('Rental Price vs. House Size')
plt.xlabel('House Size (SqFt)')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(12, 8))
seaborn.violinplot(x=df['House_type'], y=df['price'], palette='muted')
plt.title('Rental Price by House Type')
plt.xlabel('House Type')
plt.ylabel('Price')
plt.show()
# Out:
# <ipython-input-33-80a6ceb31a7e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   seaborn.violinplot(x=df['House_type'], y=df['price'], palette='muted')

# %%
plt.figure(figsize=(10, 6))
df.groupby('numBathrooms')['price'].mean().plot(kind='bar', color='coral')
plt.title('Average Rental Price by Number of Bathrooms')
plt.xlabel('Number of Bathrooms')
plt.ylabel('Average Price')

plt.figure(figsize=(10, 6))
df.groupby('num_bed')['price'].mean().plot(kind='bar', color='red')
plt.title('Average Rental Price by Number of Beds')
plt.xlabel('Number of Beds')
plt.ylabel('Average Price')

plt.figure(figsize=(10, 6))
df.groupby('numBalconies')['price'].mean().plot(kind='bar', color='brown')
plt.title('Average Rental Price by Number of Balconies')
plt.xlabel('Number of Balconies')
plt.ylabel('Average Price')
plt.show()

# %%
df_corr = df.corr(numeric_only=True)

# %%
seaborn.heatmap(df_corr,cmap='coolwarm',annot=True)
plt.show()

# %%
y = df['price']
x = df[['house_size(SqFt)', 'numBathrooms', 'numBalconies','distance_to_center']]
model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  price   R-squared (uncentered):                   0.889
# Model:                            OLS   Adj. R-squared (uncentered):              0.889
# Method:                 Least Squares   F-statistic:                              9638.
# Date:                Fri, 27 Dec 2024   Prob (F-statistic):                        0.00
# Time:                        14:31:47   Log-Likelihood:                         -61148.
# No. Observations:                4803   AIC:                                  1.223e+05
# Df Residuals:                    4799   BIC:                                  1.223e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# house_size(SqFt)      59.6208      1.068     55.807      0.000      57.526      61.715
# numBathrooms        2.137e+04   1869.970     11.428      0.000    1.77e+04     2.5e+04
# numBalconies       -2.142e+04   1286.798    -16.643      0.000   -2.39e+04   -1.89e+04
# distance_to_center   -21.3974     56.142     -0.381      0.703    -131.461      88.666
# ==============================================================================
# Omnibus:                      520.194   Durbin-Watson:                   1.132
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              786.910
# Skew:                           0.801   Prob(JB):                    1.33e-171
# Kurtosis:                       4.169   Cond. No.                     6.52e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 6.52e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LinearRegression
new_data = {
    'house_size(SqFt)': [500,500,500,500,400]
    ,'numBathrooms': [5,5,5,4,5]
    ,'numBalconies': [5,5,4,5,5]
    ,'distance_to_center': [5,10,5,5,5]
}
new_data_df = pd.DataFrame(new_data)
predictions = model.predict(new_data_df)
print(predictions)
# Out:
# 0   29474.02
# 1   29367.03
# 2   50889.82
# 3    8104.10
# 4   23511.94
# dtype: float64

# %%
y = df['price']
X = df[['house_size(SqFt)', 'numBathrooms', 'numBalconies','distance_to_center']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

predictions = model.predict(X_test)

linear_mse = np.mean((y_test - predictions) ** 2)
linear_rmse = np.sqrt(linear_mse)
linear_r2 = model.rsquared
print('mse:',linear_mse)
print('rmse:',linear_rmse)
print('R-squared:', linear_r2)
# Out:
# mse: 6666737023.484319
# rmse: 81650.08893739381
# R-squared: 0.8893017990174952

# %%
df['price'].describe()
# Out:
# count     4803.00
# mean    179790.15
# std     167765.83
# min       3000.00
# 25%      27500.00
# 50%     110000.00
# 75%     301022.00
# max     704405.00
# Name: price, dtype: float64

# %%
df_encoding = pd.get_dummies(df, columns=['Status', 'BHK/RK', 'House_type'], drop_first=True)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder
y = df_encoding['price']
x = df_encoding.drop('price', axis=1)

# %%
# Fitting Random Forest Regression to the dataset
regressor = RandomForestRegressor(n_estimators=100, random_state=0, oob_score=True)
# Fit the regressor with x and y data
regressor.fit(x, y)
# Out:
# RandomForestRegressor(oob_score=True, random_state=0)

# %%
# Evaluating the model
from sklearn.metrics import mean_squared_error, r2_score

# Access the OOB Score
oob_score = regressor.oob_score_
print(f'Out-of-Bag Score: {oob_score}')

# Making predictions on the same data or new data
predictions = regressor.predict(x)

# Evaluating the model
rf_mse = mean_squared_error(y, predictions)
print(f'Mean Squared Error: {rf_mse}')

r2 = r2_score(y, predictions)
print(f'R-squared: {r2}')
# Out:
# Out-of-Bag Score: 0.8888006805164649
# Mean Squared Error: 1624925868.4555562
# R-squared: 0.9422546596482569

# %%
# Assuming `regressor` is your fitted Random Forest model
feature_importances = regressor.feature_importances_

# Get feature names
feature_names = x.columns

# Create a DataFrame for feature importances
importance_df1 = pd.DataFrame({
    'Feature'   : feature_names,
    'Importance': feature_importances
})

# Sort the DataFrame by importance
importance_df1 = importance_df1.sort_values(by='Importance', ascending=False)

# Display the DataFrame
print(importance_df1)
# Out:
#                    Feature  Importance
# 5         house_size(SqFt)        0.89
# 1                longitude        0.03
# 0                 latitude        0.03
# 3             numBalconies        0.01
# 10  House_type_Independent        0.01
# 8       Status_Unfurnished        0.01
# 6       distance_to_center        0.01
# 4                  num_bed        0.01
# 2             numBathrooms        0.01
# 12        House_type_Villa        0.00
# 7    Status_Semi-Furnished        0.00
# 13    House_type_penthouse        0.00
# 9                BHK/RK_RK        0.00
# 11       House_type_Studio        0.00

# %%
df.head()
# Out:
#    latitude  longitude  price  numBathrooms  numBalconies          Status  \
# 0     28.55      77.25  22000             1          3.00       Furnished
# 1     28.64      77.13  20000             1          3.00       Furnished
# 2     28.62      77.05   8500             1          3.00  Semi-Furnished
# 3     28.71      77.18  48000             3          3.00       Furnished
# 4     28.72      77.13  20000             2          3.00     Unfurnished
#
#    num_bed BHK/RK   House_type  house_size(SqFt)  distance_to_center
# 0        1     RK       Studio               400                  15
# 1        1     RK       Studio               400                   9
# 2        2    BHK  Independent               500                  17
# 3        3    BHK  Independent              1020                   5
# 4        2    BHK    Apartment               810                  10

# %%
import xgboost as xgb
from xgboost import XGBRegressor

# Initialize the model
xgb_model = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Fit the model
xgb_model.fit(X_train, y_train)

# Predict on the test set
xgb_predictions = xgb_model.predict(X_test)

# Evaluate the model
xgb_mse = mean_squared_error(y_test, xgb_predictions)
xgb_r2 = r2_score(y_test, xgb_predictions)
print(f'XGBoost - MSE: {xgb_mse}')
print(f'XGB R2: {xgb_r2}')
# Plot feature importance based on weight
xgb.plot_importance(xgb_model, importance_type='weight')
plt.title('Feature Importance by Weight')
plt.show()

# Plot feature importance based on gain
xgb.plot_importance(xgb_model, importance_type='gain')
plt.title('Feature Importance by Gain')
plt.show()

# Plot feature importance based on cover
xgb.plot_importance(xgb_model, importance_type='cover')
plt.title('Feature Importance by Cover')
plt.show()
# Out:
# XGBoost - MSE: 3893030400.0
# XGB R2: 0.8611886501312256

# %%
# Collecting the results
results_dict = {
    'Model': ['Linear Regression', 'Random Forest', 'XGBoost'],
    'MSE': [linear_mse, rf_mse, xgb_mse],
    'R-squared': [linear_r2, r2, xgb_r2],
    'OOB Score': [None, oob_score, None]  # Only Random Forest has OOB score
}

# Create the DataFrame
results_df = pd.DataFrame(results_dict)

# Display the DataFrame
print(results_df)
# Out:
#                Model           MSE  R-squared  OOB Score
# 0  Linear Regression 6666737023.48       0.89        NaN
# 1      Random Forest 1624925868.46       0.94       0.89
# 2            XGBoost 3893030400.00       0.86        NaN
